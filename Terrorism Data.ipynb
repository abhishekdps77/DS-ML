# %% [markdown]
# ## Q1
# #### Problem-1 : Terror Attack City
# Problem Statement :
# The Most Dangerous city in Jammu and Kashmir and the terrorist group which is most active in that city?
# Print count of number of attacks in that city as integer value.
# Note:Ignoring the Unknown Terrorist Group.Here Dangerous related with the number of terrorist attacks.

# %%
import pandas as pd

# %%
df = pd.read_csv('terrorismData.csv')

# %%
df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %%
df.shape
# Out:
# (181691, 17)

# %%
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
df1 = df[df.State=='Jammu and Kashmir']
print("Shape: ",df1.shape)
df1
# Out:
# Shape:  (2454, 17)
#         Year  Month  Day Country              State      Region  \
# 21744   1984      4   17   India  Jammu and Kashmir  South Asia
# 22108   1984      5   20   India  Jammu and Kashmir  South Asia
# 29677   1986     12   11   India  Jammu and Kashmir  South Asia
# 33202   1988      1   21   India  Jammu and Kashmir  South Asia
# 33372   1988      2    7   India  Jammu and Kashmir  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181222  2017     12   11   India  Jammu and Kashmir  South Asia
# 181396  2017     12   18   India  Jammu and Kashmir  South Asia
# 181414  2017     12   19   India  Jammu and Kashmir  South Asia
# 181476  2017     12   22   India  Jammu and Kashmir  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
#
#                       City   Latitude  Longitude         AttackType  Killed  \
# 21744                Bhela  33.315527  74.622476      Assassination     2.0
# ...

# %%
df_list = df1['City'].value_counts()
city = df_list.index[0]
attacks = df_list.values[0]
print("Most Dangerous City: ", city)
print("No of attacks: ",attacks)

df2=df1[df1.City==city]
df2['Group'].value_counts()

terroristGroup = df2['Group'].value_counts().index[1]
print("Most active terror group:" , terroristGroup)
# Out:
# Most Dangerous City:  Srinagar
# No of attacks:  657
# Most active terror group: Muslim Separatists

# %% [markdown]
# ## Q2
#
# #### Problem-2 : Terror Attack
# Problem Statement :
# Find out the Country with Highest Number of Terror Attack and in which year the most number of terrorist attack happened in that country ?
# Print count of terror attacks as integer value.

# %%
import pandas as pd
df= pd.read_csv('terrorismData.csv')
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
country = df['Country'].value_counts().index[0]
print('Country with highest number of terrorist attacks: ', country)
# Out:
# Country with highest number of terrorist attacks:  Iraq

# %%
df1 = df[df.Country==country]
year = df1.Year.value_counts().index[0]
print("Year in which most attack happended: ", year)
# Out:
# Year in which most attack happended:  2014

# %%
print('Country with highest number of terrorist attacks: ', country)
print("Year in which most attack happended: ", year)
# Out:
# Country with highest number of terrorist attacks:  Iraq
# Year in which most attack happended:  2014

# %% [markdown]
# ## Q3
# #### Problem-3 : Terror DeadliestAttack
# Problem Statement :
# Most Deadliest attack in a history of HumanKind?
# Print count of Killed people as integer value.
# Note: Here Deadliest attack means, in which the most number of people killed.

# %%
df.shape
# Out:
# (181691, 17)

# %%
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
maxKilled = df.Killed.max()
maxKilled
# Out:
# 1570.0

# %%
df1=df[df.Killed == maxKilled]
mx_killed = df1.Killed.iloc[0]
country = df1.Country.iloc[0]
group = df1.Group.iloc[0]
print(int(mx_killed), country, group)
# Out:
# 1570 Iraq Islamic State of Iraq and the Levant (ISIL)

# %% [markdown]
# ## Q4

# %%
df
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
df1 = df[df.Year>=2014]
df1.head()
# Out:
#         Year  Month  Day   Country               State              Region  \
# 125335  2014      1    1  Colombia  Norte de Santander       South America
# 125336  2014      1    1   Somalia            Banaadir  Sub-Saharan Africa
# 125337  2014      1    1  Pakistan         Balochistan          South Asia
# 125338  2014      1    1  Pakistan         Balochistan          South Asia
# 125339  2014      1    1   Somalia         Middle Juba  Sub-Saharan Africa
#
#               City   Latitude  Longitude                   AttackType  Killed  \
# 125335  Convencion   8.868790 -73.194094            Bombing/Explosion     0.0
# 125336   Mogadishu   2.059819  45.326115            Bombing/Explosion     4.0
# 125337      Quetta  30.200819  66.994354            Bombing/Explosion     3.0
# 125338  Dera Bugti  29.034412  69.158661            Bombing/Explosion     0.0
# 125339       Buale   1.097128  42.598368  Hostage Taking (Kidnapping)     NaN
#
#         Wounded                   Target  \
# ...

# %%
df2 = df1[df1.Month>=5]
df2.head()
# Out:
#         Year  Month  Day   Country    State          Region         City  \
# 127864  2014      5   24  Thailand  Pattani  Southeast Asia     Sabarang
# 127865  2014      5   24  Thailand  Pattani  Southeast Asia  Paka Harang
# 127866  2014      5   24  Thailand  Pattani  Southeast Asia  Paka Harang
# 127867  2014      5   24  Thailand  Pattani  Southeast Asia     Sabarang
# 127868  2014      5   24  Thailand  Pattani  Southeast Asia   Rusa Milae
#
#         Latitude   Longitude         AttackType  Killed  Wounded Target  \
# 127864  6.867859  101.252068  Bombing/Explosion     1.0      5.0  Store
# 127865  6.867859  101.252068  Bombing/Explosion     1.0      5.0  Store
# 127866  6.867859  101.252068  Bombing/Explosion     1.0      5.0  Store
# 127867  6.867859  101.252068  Bombing/Explosion     0.0      5.0  Store
# 127868  6.873954  101.234711  Bombing/Explosion     0.0      5.0  Store
#
#                                                   Summary        Group  \
# ...

# %%
df3 = df2[df2.Day>=26]
df3.head()
# Out:
#         Year  Month  Day   Country        State                      Region  \
# 132357  2014      5   26     Kenya         Lamu          Sub-Saharan Africa
# 132450  2014      5   26     Libya     Benghazi  Middle East & North Africa
# 132451  2014      5   26     Libya     Benghazi  Middle East & North Africa
# 132452  2014      5   26     Yemen        Marib  Middle East & North Africa
# 132453  2014      5   26  Pakistan  Balochistan                  South Asia
#
#                    City   Latitude  Longitude                   AttackType  \
# 132357             Lamu  -2.256599  40.908075                Armed Assault
# 132450         Benghazi  32.069286  20.151144                Assassination
# 132451         Benghazi  32.094952  20.268871            Bombing/Explosion
# 132452  Sirwah district  15.459390  45.023548  Hostage Taking (Kidnapping)
# 132453            Kalat  29.047852  66.593323            Bombing/Explosion
#
# ...

# %%
df4 = df3[df3.Country=='India']
df4.head()
# Out:
#         Year  Month  Day Country              State      Region          City  \
# 132468  2014      5   26   India     Andhra Pradesh  South Asia   Bandlapalli
# 132496  2014      5   26   India        West Bengal  South Asia  Sandeshkhali
# 132502  2014      5   26   India        West Bengal  South Asia  Sandeshkhali
# 132526  2014      5   27   India  Jammu and Kashmir  South Asia         Khour
# 132555  2014      5   27   India             Odisha  South Asia     Bikrampur
#
#          Latitude  Longitude         AttackType  Killed  Wounded  \
# 132468  14.714739  77.810281  Bombing/Explosion     0.0      0.0
# 132496  22.356709  88.881991      Armed Assault     0.0     12.0
# 132502  22.363882  88.878679      Armed Assault     0.0     11.0
# 132526  32.601778  74.809414  Bombing/Explosion     0.0      0.0
# 132555  22.338542  86.178146      Assassination     1.0      0.0
#
#                                  Target  \
# 132468                  Party Supporter
# ...

# %%
df4.shape[0]
# Out:
# 478

# %%
df4['Group'].value_counts().index[1]
# Out:
# 'Maoists'

# %%
print(df4.shape[0], df4['Group'].value_counts().index[1])
# Out:
# 478 Maoists

# %% [markdown]
# ## Q5
# Problem-5 : Terror Frequency
# Problem Statement :
# Find the frequency of the Casualty in Red Corridor states and in Jammu and Kashmir ?Here Frequency is (Total Casualty/Total Number of a year)
# Print frequency as integer value.
# Note:Red Corridor state includes Jharkhand, Odisha, Andhra Pradesh, and Chhattisgarh. Here Casualty=Killed +Wounded.Don't fill the nan value present in Killed and Wounded feature.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('terrorismData.csv')

year = len(set(df['Year']))

df = df[df.Country == 'India']
df['Casualty'] = df['Killed'] + df['Wounded']

jk = df[df.State == 'Jammu and Kashmir']
rc = df[(df.State == 'Jharkhand') | (df.State == 'Odisha') | (df.State == 'Andhra Pradesh') | (df.State == 'Chhattisgarh')]

jkc = int(np.sum(jk['Casualty']))
rcc = int(np.sum(rc['Casualty']))

print(rcc//year,jkc//year)
# Out:
# 115 261
